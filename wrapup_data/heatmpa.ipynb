# %%
import numpy as np
import json
import matplotlib.pyplot as plt
import os
os.chdir('..')
from scripts.utils.utils_odfn import variance_5_class_index_sorted, seeds_plus

spilt = 'train'
mode = '1_category_5_class_npy'
name = spilt + '_for_' + mode + '.json'

base_path = '/nfs/data/yuanhaoban/ODFN/version_2/'
path = base_path + spilt + '/annotations/' + name
data = json.load(open(path, 'r'))
images = data['images']
annotations = data['annotations']

image_id = [variance_5_class_index_sorted[1210], variance_5_class_index_sorted[18900]]

fig, axs = plt.subplots(1, 2, figsize=(10, 5))
fig.tight_layout()
for i in range(2):
    place_holder = np.zeros((64,64),dtype=np.float32)
    for ann in annotations:
        if ann['image_id'] == image_id[i]:
            print(ann['bbox'])
            bbox = ann['bbox']
            bbox = [int(i) for i in bbox]
            place_holder[bbox[1]:bbox[3],bbox[0]:bbox[2]] += 1
        
    place_holder = place_holder / np.max(place_holder)
    axs[i].imshow(place_holder)
    
# fig.show()
fig.savefig('/home/banyh2000/odfn/wrapup_data/heatmap.png')
# Out:
# [15.039691925048828, 14.055203437805176, 53.454002380371094, 51.57570266723633]
# [0.016459045931696892, 15.08748722076416, 23.818693161010742, 49.3997802734375]
# [0.022911377251148224, 14.842055320739746, 22.426958084106445, 43.44040298461914]
# [0.010103759355843067, 15.08754825592041, 24.54067611694336, 49.363914489746094]
# [0.008879394270479679, 19.25712776184082, 22.583805084228516, 46.2174072265625]
# [0.040697019547224045, 21.004791259765625, 24.647363662719727, 54.87256622314453]
# [0.02815551683306694, 20.488027572631836, 24.6995849609375, 54.43764114379883]
# [0.010363158769905567, 14.506645202636719, 25.652299880981445, 53.73612976074219]
# [0.02593383751809597, 22.001483917236328, 25.732423782348633, 48.120361328125]
# [0.021970214322209358, 19.081344604492188, 24.368104934692383, 46.81017303466797]
# [0.016715697944164276, 18.676645278930664, 23.58467674255371, 49.24808120727539]
# [0.025673827156424522, 14.60311222076416, 25.03126335144043, 51.016849517822266]
# [0.019768066704273224, 14.42858600616455, 25.02680206298828, 50.889041900634766]
# [0.0, 15.200240135192871, 23.664323806762695, 49.8000373840332]
# [0.016840819269418716, 16.745874404907227, 22.208282470703125, 49.75812530517578]
# [43.77007293701172, 4.193940162658691, 63.92804718017578, 26.300975799560547]
# [3.5683934688568115, 12.30118179321289, 49.53003692626953, 57.00175094604492]
# [0.014454956166446209, 37.18345260620117, 15.853142738342285, 57.22032928466797]
# [13.057327270507812, 38.05839920043945, 34.081382751464844, 50.41661071777344]
# [13.423770904541016, 18.188295364379883, 27.8105411529541, 32.00302505493164]
# [20.756328582763672, 24.600379943847656, 57.18288803100586, 61.72711944580078]
# [29.168155670166016, 23.53852081298828, 57.50724792480469, 42.00226593017578]
# [0.012150879018008709, 13.705389976501465, 29.66294288635254, 44.39198303222656]
# [10.82761001586914, 26.338706970214844, 37.22311019897461, 37.603477478027344]
# [12.667961120605469, 27.315086364746094, 30.2169246673584, 35.90105056762695]
# [0.013399657793343067, 37.04727554321289, 16.168277740478516, 58.195106506347656]
# [0.0, 36.023406982421875, 16.802793502807617, 59.74573516845703]
# [39.94374084472656, 0.2937939465045929, 63.91212844848633, 32.12672805786133]
# [2.733842611312866, 15.35414981842041, 49.409637451171875, 62.024818420410156]
# [0.9088866710662842, 31.823732376098633, 32.96076202392578, 62.52806854248047]
# [0.01865844614803791, 14.279682159423828, 43.88325119018555, 60.51203155517578]

# %%
import numpy as np
import json
import matplotlib.pyplot as plt
import os
os.chdir('..')
from scripts.utils.utils_odfn import variance_5_class_index_sorted, seeds_plus, variance_index_sorted

spilt = 'train'
mode = '1_category_5_class_npy'
name = spilt + '_for_' + mode + '.json'

base_path = '/nfs/data/yuanhaoban/ODFN/version_2/'
path = base_path + spilt + '/annotations/' + name
data = json.load(open(path, 'r'))
images = data['images']
annotations = data['annotations']

image_id = variance_index_sorted[19901]
# image_id = variance_index_sorted[2]  # left 16
# image_id = variance_index_sorted[27]
# image_id = variance_index_sorted[60]
# 0 right 11
# image_id = variance_index_sorted[19910]
print(seeds_plus[image_id])
fig, axs = plt.subplots()
fig.tight_layout()
place_holder = np.zeros((64,64),dtype=np.float32)
for ann in annotations:
    if ann['image_id'] == image_id:
        print(ann['bbox'])
        bbox = ann['bbox']
        bbox = [int(i) for i in bbox]
        place_holder[bbox[1]:bbox[3],bbox[0]:bbox[2]] += 1
    
place_holder = place_holder / np.max(place_holder)
axs.imshow(place_holder)
# Out:
# 972958
# [0.07744872570037842, 2.0532493591308594, 51.02396774291992, 62.49553680419922]
# [0.06127685308456421, 16.125858306884766, 50.90840530395508, 62.092445373535156]
# [12.407514572143555, 2.152750253677368, 38.164283752441406, 15.900358200073242]
# [1.6700975894927979, 8.098601341247559, 48.992713928222656, 54.51335906982422]
# [1.5873382091522217, 28.218149185180664, 14.802721977233887, 39.97351837158203]
# [51.113006591796875, 14.041417121887207, 64.0, 37.72581100463867]
# [51.42373275756836, 13.27507209777832, 64.0, 37.84293746948242]
# [41.67776870727539, 21.04130744934082, 63.94858932495117, 44.08823013305664]
# [40.626434326171875, 20.54155731201172, 63.873191833496094, 44.68299102783203]
# [13.60485553741455, 10.13848876953125, 64.0, 51.29161071777344]
# [15.15554141998291, 10.283591270446777, 64.0, 47.393192291259766]
# [11.021657943725586, 10.537005424499512, 63.94068145751953, 48.83255386352539]
# [10.597382545471191, 0.45445311069488525, 39.22030258178711, 13.431768417358398]
# [10.893975257873535, 0.35929441452026367, 38.97765350341797, 12.687705039978027]
# [9.530583381652832, 0.5585162043571472, 41.87911605834961, 12.91355037689209]
# [30.179922103881836, 10.837575912475586, 64.0, 40.303897857666016]
# [5.840229511260986, 0.3660571277141571, 63.33967590332031, 41.39888000488281]
